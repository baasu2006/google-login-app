# %% [markdown]
# <a href="https://colab.research.google.com/github/baasu2006/google-login-app/blob/main/MILESTONE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --upgrade google-api-python-client google-auth-httplib2 google-auth-oauthlib
# !pip install SpeechRecognition gTTS
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 90.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-api-python-client
#     Found existing installation: google-api-python-client 2.189.0
#     Uninstalling google-api-python-client-2.189.0:
#       Successfully uninstalled google-api-python-client-2.189.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 61.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 9.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.3.1
#     Uninstalling click-8.3.1:
#       Successfully uninstalled click-8.3.1
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cb988de2-beb7-4c9f-8679-878bf8ba8029" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cb988de2-beb7-4c9f-8679-878bf8ba8029">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
import base64
import pickle
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build

SCOPES = ['https://www.googleapis.com/auth/gmail.modify']

creds = None

if os.path.exists('token.pickle'):
    with open('token.pickle', 'rb') as token:
        creds = pickle.load(token)

if not creds or not creds.valid:
    flow = InstalledAppFlow.from_client_secrets_file(
        'credentials.json', SCOPES)

    # Set redirect_uri for out-of-band (OOB) authentication
    flow.redirect_uri = 'urn:ietf:wg:oauth:2.0:oob'

    # Generate the authorization URL
    auth_url, _ = flow.authorization_url(prompt='consent')

    print('Please go to this URL and authorize access:')
    print(auth_url)

    # Get the authorization code from the user
    code = input('Enter the authorization code: ')

    # Exchange the authorization code for credentials
    flow.fetch_token(code=code)
    creds = flow.credentials

    with open('token.pickle', 'wb') as token:
        pickle.dump(creds, token)

service = build('gmail', 'v1', credentials=creds)

print(" Gmail Login Successful!")
# Out:
# Please go to this URL and authorize access:
# https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=666795607884-t6mcq7htfoa92lr5c8b79iuuiknqkiga.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.modify&state=PT99zPMUpCSDKIeSWyeatyVqiMVdQh&prompt=consent&access_type=offline
# Enter the authorization code: 4/1AfrIepA4Uiix1DSEKuHTF15C7SqHOG16Km_RMSxmC80rz06K6PtkzFEfb5M
#  Gmail Login Successful!

# %%
import json
import os

PROFILE_FILE = "user_preferences.json"

# Load preferences
def load_preferences():
    if os.path.exists(PROFILE_FILE):
        with open(PROFILE_FILE, "r") as f:
            return json.load(f)
    return {}

# Save preferences
def save_preferences(data):
    with open(PROFILE_FILE, "w") as f:
        json.dump(data, f, indent=4)

# Create / Update Preferences
def set_preferences():
    prefs = load_preferences()

    username = input("Enter username: ")

    print("\nSelect Language:")
    print("1. English")
    print("2. Hindi")
    print("3. Telugu")
    lang_choice = input("Enter choice: ")

    languages = {
        "1": "English",
        "2": "Hindi",
        "3": "Telugu"
    }

    language = languages.get(lang_choice, "English")

    print("\nTheme Preference:")
    print("1. Light")
    print("2. Dark")
    theme_choice = input("Enter choice: ")

    theme = "Light" if theme_choice == "1" else "Dark"

    voice = input("\nEnable Voice Assistant? (yes/no): ").lower()
    email_reading = input("Read only unread emails? (yes/no): ").lower()

    prefs[username] = {
        "language": language,
        "theme": theme,
        "voice_enabled": voice == "yes",
        "read_unread_only": email_reading == "yes"
    }

    save_preferences(prefs)
    print(" Preferences Saved Successfully!")

# View Preferences
def view_preferences():
    prefs = load_preferences()
    username = input("Enter username to view preferences: ")

    if username in prefs:
        print("\n User Preferences:")
        for key, value in prefs[username].items():
            print(f"{key.replace('_',' ').capitalize()}: {value}")
    else:
        print("No preferences found.")

# Menu
def menu():
    while True:
        print("\n===== USER PREFERENCES =====")
        print("1. Set Preferences")
        print("2. View Preferences")
        print("3. Exit")

        choice = input("Enter choice: ")

        if choice == "1":
            set_preferences()
        elif choice == "2":
            view_preferences()
        elif choice == "3":
            break
        else:
            print(" Invalid choice!")

menu()
# Out:
# ===== USER PREFERENCES =====
# 1. Set Preferences
# 2. View Preferences
# 3. Exit
# Enter choice: 1
# Enter username: Baavana arvapalli
#
# Select Language:
# 1. English
# 2. Hindi
# 3. Telugu
# Enter choice: 1
#
# Theme Preference:
# 1. Light
# 2. Dark
# Enter choice: 1
#
# Enable Voice Assistant? (yes/no): yes
# Read only unread emails? (yes/no): yes
#  Preferences Saved Successfully!
#
# ===== USER PREFERENCES =====
# 1. Set Preferences
# 2. View Preferences
# 3. Exit
# Enter choice: 2
# Enter username to view preferences: Baavana
# No preferences found.
#
# ===== USER PREFERENCES =====
# 1. Set Preferences
# 2. View Preferences
# 3. Exit
# Enter choice: Baavana Arvapalli
#  Invalid choice!
#
# ===== USER PREFERENCES =====
# 1. Set Preferences
# 2. View Preferences
# 3. Exit
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...

# %%
# !pip install SpeechRecognition gTTS pydub

# %%
from IPython.display import Javascript, display
from google.colab import output
import base64
import io
import speech_recognition as sr
from pydub import AudioSegment

RECORD = """
const sleep = time => new Promise(resolve => setTimeout(resolve, time))
const b2text = blob => new Promise(resolve => {
  const reader = new FileReader()
  reader.onloadend = e => resolve(e.target.result)
  reader.readAsDataURL(blob)
})

var recorder, gumStream;
var audioContext = new (window.AudioContext || window.webkitAudioContext)();

navigator.mediaDevices.getUserMedia({audio: true}).then(stream => {
  gumStream = stream;
  recorder = new MediaRecorder(stream);
  recorder.start();

  sleep(5000).then(() => {  // 🎤 RECORDING TIME (5 seconds)
    recorder.stop();
    gumStream.getAudioTracks()[0].stop();
  });

  recorder.ondataavailable = async e => {
    let data = await b2text(e.data);
    google.colab.kernel.invokeFunction('notebook.save_audio', [data], {});
  }
});
"""

audio_bytes = None

def save_audio(data):
    global audio_bytes
    audio_bytes = base64.b64decode(data.split(',')[1])

output.register_callback('notebook.save_audio', save_audio)

display(Javascript(RECORD))

# %%
if audio_bytes is None:
    print("❌ Audio recording failed or did not complete. Please ensure the previous cell (cell Z4vc5eFfXeOf) has finished recording and run it again if necessary.")
else:
    with open("speech.wav", "wb") as f:
        f.write(audio_bytes)

    sound = AudioSegment.from_file("speech.wav")
    sound.export("speech.wav", format="wav")

    recognizer = sr.Recognizer()

    with sr.AudioFile("speech.wav") as source:
        audio = recognizer.record(source)

    try:
        text = recognizer.recognize_google(audio)
        print("🗣️ You said:", text)
    except:
        print("❌ Could not recognize speech")
# Out:
# 🗣️ You said: I'm from the hospital

# %%
from gtts import gTTS
from IPython.display import Audio, display

tts = gTTS(text=text, lang='en')
tts.save("output.mp3")

display(Audio("output.mp3"))
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import base64
from gtts import gTTS
from IPython.display import Audio

# Get latest message
results = service.users().messages().list(
    userId='me',
    maxResults=1
).execute()

messages = results.get('messages', [])

if not messages:
    print("No emails found.")
else:
    msg = service.users().messages().get(
        userId='me',
        id=messages[0]['id'],
        format='full'
    ).execute()

    payload = msg['payload']
    headers = payload.get('headers')

    sender = ""
    subject = ""
    body = ""

    # Extract From & Subject
    for header in headers:
        if header['name'] == 'From':
            sender = header['value']
        if header['name'] == 'Subject':
            subject = header['value']

    # Function to extract body
    def get_body(parts):
        for part in parts:
            if part['mimeType'] == 'text/plain':
                data = part['body']['data']
                return base64.urlsafe_b64decode(data).decode()
            elif part['mimeType'] == 'multipart/alternative':
                return get_body(part['parts'])
        return None

    if 'parts' in payload:
        body = get_body(payload['parts'])
    else:
        body = base64.urlsafe_b64decode(
            payload['body']['data']).decode()

    print("\n📩 Latest Email\n")
    print("From:", sender)
    print("Subject:", subject)
    print("\nBody:\n", body)

    # 🔊 Create speech text
    speech_text = f"You have a new email from {sender}. The subject is {subject}. The message says {body}"

    # Convert to speech
    tts = gTTS(text=speech_text, lang='en')
    tts.save("latest_email.mp3")

    # Play audio
    Audio("latest_email.mp3", autoplay=True)

# %%
from gtts import gTTS
from IPython.display import Audio, display

short_body = body[:800]

speech_text = f"You have a new email from {sender}. The subject is {subject}. The message says {short_body}"

tts = gTTS(text=speech_text, lang='en')
tts.save("latest_email.mp3")

display(Audio("latest_email.mp3"))
